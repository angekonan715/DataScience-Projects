# %% [markdown]
# <a href="https://colab.research.google.com/github/angekonan715/DataScience-Projects/blob/main/starter_bankProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
# !pip install lets_plot
from lets_plot import *
LetsPlot.setup_html()
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
campaign = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank.csv')

# %%
campaign.info()
campaign.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37069 entries, 0 to 37068
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37069 non-null  int64
#  1   job             37069 non-null  object
#  2   marital         37069 non-null  object
#  3   education       37069 non-null  object
#  4   default         37069 non-null  object
#  5   housing         37069 non-null  object
#  6   loan            37069 non-null  object
#  7   contact         37069 non-null  object
#  8   month           37069 non-null  object
#  9   day_of_week     37069 non-null  object
#  10  campaign        37069 non-null  int64
#  11  pdays           37069 non-null  int64
#  12  previous        37069 non-null  int64
#  13  poutcome        37069 non-null  object
#  14  emp.var.rate    37069 non-null  float64
#  15  cons.price.idx  37069 non-null  float64
#  16  cons.conf.idx   37069 non-null  float64
# ...

# %%
ggplot(campaign, aes(x='cons.price.idx', y = 'cons.conf.idx')) +\
 geom_point() +\
 geom_smooth(method='lm') +\
 labs(title='Consumer Price Index vs Consumer Confidence Index')
# Out:
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <style> html, body { margin: 0; padding: 0; } </style>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="IRO4Hw"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("IRO4Hw");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# ...

# %%
#relationship between cons.price.idx and y
ggplot(campaign, aes(x='cons.price.idx', y = 'y')) +\
 geom_point() +\
 geom_smooth(method='lm') +\
 labs(title='Consumer Price Index vs Subscription')
# Out:
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <style> html, body { margin: 0; padding: 0; } </style>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="kYNebC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("kYNebC");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "data":{
# ...

# %% [markdown]
# ## Data Explorartion
#
# *Missing Value*

# %%
# 5 first rows
campaign.head()
# campaign.default.value_counts()
#great
campaign.info()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
campaign.loan.value_counts()
# Out:
# loan
# no         30590
# yes         5585
# unknown      894
# Name: count, dtype: int64

# %%
campaign.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 37064   73      retired  married  professional.course      no     yes   no
# 37065   46  blue-collar  married  professional.course      no      no   no
# 37066   56      retired  married    university.degree      no     yes   no
# 37067   44   technician  married  professional.course      no      no   no
# 37068   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  campaign  pdays  previous     poutcome  \
# 37064  cellular   nov         fri         1    999         0  nonexistent
# 37065  cellular   nov         fri         1    999         0  nonexistent
# 37066  cellular   nov         fri         2    999         0  nonexistent
# 37067  cellular   nov         fri         1    999         0  nonexistent
# 37068  cellular   nov         fri         3    999         1      failure
#
# ...

# %%
# replace value 999 from the pdays column to 0
#campaign['pdays'] = campaign['pdays'].replace(999, 0)
campaign.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
# campaign['campaign'] = campaign['campaign'].astype('category')

# Encode our features and target as needed
features = ['job',
            'loan',
            'housing',
            #'month',
            'day_of_week',
            'pdays',
            'campaign',
            'poutcome',
            'education',
            'emp.var.rate',
            #'default',
            'cons.price.idx',
            'cons.conf.idx',
            'euribor3m',
            'nr.employed'

            ]
#campaign_filtered = campaign.drop(columns=['y', 'default'])
#campaign_filtered = campaign_filtered.filter(regex='^(?!.*unknown).*$', axis=1)
X = pd.get_dummies(campaign[features], drop_first=True)
#X = X.filter(regex='^(?!.*unknown).*$', axis=1)
y = campaign['y']

# %%
X.columns
X.head()
# Out:
# Index(['pdays', 'campaign', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'job_blue-collar', 'job_entrepreneur',
#        'job_housemaid', 'job_management', 'job_retired', 'job_self-employed',
#        'job_services', 'job_student', 'job_technician', 'job_unemployed',
#        'job_unknown', 'loan_unknown', 'loan_yes', 'housing_unknown',
#        'housing_yes', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue',
#        'day_of_week_wed', 'poutcome_nonexistent', 'poutcome_success',
#        'education_basic.6y', 'education_basic.9y', 'education_high.school',
#        'education_illiterate', 'education_professional.course',
#        'education_university.degree', 'education_unknown', 'default_unknown',
#        'default_yes'],
#       dtype='object')
# ...

# %%
# Split our data into training and test data, with 30% reserved for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# Build the decision tree
clf = DecisionTreeClassifier(class_weight='balanced', random_state=42)

# Train it
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# Test it
clf.score(X_test, y_test)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=42)
# 0.8065821418937146

# %%
## test our model
y_pred = clf.predict(X_test)
## Evaluate our classification model: Decision tree
clf_report = metrics.classification_report(y_pred, y_test)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#           no       0.87      0.91      0.89      6247
#          yes       0.34      0.25      0.29      1167
#
#     accuracy                           0.81      7414
#    macro avg       0.60      0.58      0.59      7414
# weighted avg       0.78      0.81      0.79      7414

# %%
# Access feature importance scores
feature_importances = clf.feature_importances_

# Create a DataFrame to display feature importances alongside feature names
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})

# Sort by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the DataFrame
print(feature_importance_df)
# Create a bar plot
# Create a ggplot bar plot
ggplot(feature_importance_df, aes(x='Feature', y='Importance')) + \
    geom_bar() + \
    coord_flip() + \
    labs(title='Feature Importance in Decision Tree', x='Feature', y='Importance')
# Out:
#                           Feature  Importance
# 6                     nr.employed    0.226738
# 1                        campaign    0.115314
# 5                       euribor3m    0.111320
# 4                   cons.conf.idx    0.068627
# 21                    housing_yes    0.049148
# 19                       loan_yes    0.030000
# 30          education_high.school    0.028950
# 15                 job_technician    0.026975
# 7                 job_blue-collar    0.023402
# 33    education_university.degree    0.021803
# 23                day_of_week_thu    0.021627
# 3                  cons.price.idx    0.020771
# 25                day_of_week_wed    0.020244
# 24                day_of_week_tue    0.020198
# 29             education_basic.9y    0.019602
# 10                 job_management    0.018301
# 22                day_of_week_mon    0.017115
# 0                           pdays    0.016465
# 13                   job_services    0.016455
# ...

# %%
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
#PREDICT ON THE MINI DATASET
bank_hold_mini = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bank_holdout_test_mini.csv')
#assign the same features to the mini dataset
mini_X = pd.get_dummies(bank_hold_mini[features])
#filter mini with all the columns of X not features
mini_X, _ = mini_X.align(X, join='inner', axis=1)
# mini_X = mini_X[['pdays', 'campaign',
#                         'poutcome_nonexistent', 'poutcome_success',
#                         'education_basic.6y', 'education_basic.9y',
#                         'education_high.school','education_illiterate',
#                         'education_professional.course','education_university.degree',
#                         'education_unknown']]
 #make a predictions column, filled in with the predictions
mini_X['predictions (y)'] = clf.predict(mini_X)
mini_X['predictions (y)'] = mini_X['predictions (y)'].replace('no',0)
mini_X['predictions (y)'] = mini_X['predictions (y)'].replace('yes',1)
predictions = mini_X['predictions (y)']
# Out:
# <ipython-input-179-6fc24f9943e7>:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mini_X['predictions (y)'] = mini_X['predictions (y)'].replace('yes',1)

# %%
mini_X
# Out:
#      pdays  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      999         2           1.4          93.918          -42.7      4.962
# 1      999         1          -1.8          92.893          -46.2      1.344
# 2        3         1          -1.7          94.055          -39.8      0.739
# 3      999        12           1.4          94.465          -41.8      4.959
# 4      999         1          -0.1          93.200          -42.0      4.120
# ..     ...       ...           ...             ...            ...        ...
# 405    999         3          -1.8          92.893          -46.2      1.250
# 406    999         9           1.4          93.918          -42.7      4.962
# 407    999         1           1.4          94.465          -41.8      4.967
# 408    999         1          -0.1          93.200          -42.0      4.021
# 409    999         1          -1.8          92.893          -46.2      1.334
#
# ...

# %%
# Download my predictions columns as csv
from google.colab import files
predictions.to_csv('predictions.csv')
files.download('predictions.csv')

# %%
mini_X['education_basic.6y'].value_counts()

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
